# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("/content/astronauts.csv")

# %%
data
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %%
data.ndim
# Out:
# 2

# %%
data.shape
# Out:
# (357, 19)

# %%
data.sample(10)
# Out:
#                           Name    Year  Group    Status  Birth Date  \
# 299           Loren J. Shriver  1978.0    8.0   Retired   9/23/1944
# 58   Manley Lanier Carter Jr.   1984.0   10.0  Deceased   8/15/1947
# 85    Frank L. Culbertson Jr.   1984.0   10.0   Retired   5/15/1949
# 209               G. David Low  1984.0   10.0  Deceased   2/19/1956
# 79       L. Gordon Cooper Jr.   1959.0    1.0  Deceased    3/6/1927
# 48            Daniel W. Bursch  1990.0   13.0   Retired   7/25/1957
# 143         Fred W. Haise Jr.   1966.0    5.0   Retired  11/14/1933
# 19              Ellen S. Baker  1984.0   10.0   Retired   4/27/1953
# 12             Jerome Apt III   1985.0   11.0   Retired   4/18/1949
# 301           Michael J. Smith  1980.0    9.0  Deceased   4/30/1945
#
#            Birth Place  Gender  \
# 299      Jefferson, IA    Male
# 58           Macon, GA    Male
# 85      Charleston, SC    Male
# 209      Cleveland, OH    Male
# 79         Shawnee, OK    Male
# ...

# %%
data.columns
# Out:
# Index(['Name', 'Year', 'Group', 'Status', 'Birth Date', 'Birth Place',
#        'Gender', 'Alma Mater', 'Undergraduate Major', 'Graduate Major',
#        'Military Rank', 'Military Branch', 'Space Flights',
#        'Space Flight (hr)', 'Space Walks', 'Space Walks (hr)', 'Missions',
#        'Death Date', 'Death Mission'],
#       dtype='object')

# %%
data.head()
# Out:
#                Name    Year  Group   Status Birth Date    Birth Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma Mater     Undergraduate Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
data.rename(columns={

                     "Birth Date":"Birth_Date",
                     "Birth Place" : "Birth_Place" ,
                      "Alma Mater" : "Alma_Mater",
                     "Undergraduate Major" : "Undergraduate_Major",
                     "Graduate Major" : "Graduate_Major",
                     "Military Rank" : "Military_Rank",
                     "Space Flights" : "Space_Flights",
                     "Space Flight (hr)" : "Space_Flights_hr",
                     "Space Walks" : "Space_Walks",
                     "Space Walks (hr)" : "Space_Walks_hr",
                     "Death Date" : "Death_Date",
                     "Death Mission" : "Death_Mission",
} , inplace=True)

# %%
data.rename(columns={

              "Military Branch":"Military_Branch"

} , inplace = True)
data.head()
# Out:
#                Name    Year  Group   Status Birth_Date    Birth_Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma_Mater     Undergraduate_Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 357 entries, 0 to 356
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 357 non-null    object
#  1   Year                 330 non-null    float64
#  2   Group                330 non-null    float64
#  3   Status               357 non-null    object
#  4   Birth_Date           357 non-null    object
#  5   Birth_Place          357 non-null    object
#  6   Gender               357 non-null    object
#  7   Alma_Mater           356 non-null    object
#  8   Undergraduate_Major  335 non-null    object
#  9   Graduate_Major       298 non-null    object
#  10  Military_Rank        207 non-null    object
#  11  Military_Branch      211 non-null    object
#  12  Space_Flights        357 non-null    int64
#  13  Space_Flights_hr     357 non-null    int64
#  14  Space_Walks          357 non-null    int64
# ...

# %%
data["Death_Mission"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 352    NaN
# 353    NaN
# 354    NaN
# 355    NaN
# 356    NaN
# Name: Death_Mission, Length: 357, dtype: object

# %%
data["Death_Mission"].isnull().sum()
data["Death_Mission"].shape
# Out:
# (357,)

# %%
# Check 'not null numbers' from here

sum = data[data["Death_Mission"].notnull()]

# sum.head()

sum.shape
# Out:
# (16, 19)

# %%
data.isnull()
# Out:
#       Name   Year  Group  Status  Birth_Date  Birth_Place  Gender  Alma_Mater  \
# 0    False  False  False   False       False        False   False       False
# 1    False   True   True   False       False        False   False       False
# 2    False  False  False   False       False        False   False       False
# 3    False  False  False   False       False        False   False       False
# 4    False  False  False   False       False        False   False       False
# ..     ...    ...    ...     ...         ...          ...     ...         ...
# 352  False  False  False   False       False        False   False       False
# 353  False  False  False   False       False        False   False       False
# 354  False  False  False   False       False        False   False       False
# 355  False  False  False   False       False        False   False       False
# 356  False  False  False   False       False        False   False       False
#
# ...

# %%
data.isnull()
# Out:
#       Name   Year  Group  Status  Birth_Date  Birth_Place  Gender  Alma_Mater  \
# 0    False  False  False   False       False        False   False       False
# 1    False   True   True   False       False        False   False       False
# 2    False  False  False   False       False        False   False       False
# 3    False  False  False   False       False        False   False       False
# 4    False  False  False   False       False        False   False       False
# ..     ...    ...    ...     ...         ...          ...     ...         ...
# 352  False  False  False   False       False        False   False       False
# 353  False  False  False   False       False        False   False       False
# 354  False  False  False   False       False        False   False       False
# 355  False  False  False   False       False        False   False       False
# 356  False  False  False   False       False        False   False       False
#
# ...

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                    27
# Group                   27
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               1
# Undergraduate_Major     22
# Graduate_Major          59
# Military_Rank          150
# Military_Branch        146
# Space_Flights            0
# Space_Flights_hr         0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                23
# Death_Date             305
# Death_Mission          341
# dtype: int64

# %%
data.notnull().sum()

# The sum of all those values which are not null
# Out:
# Name                   357
# Year                   330
# Group                  330
# Status                 357
# Birth_Date             357
# Birth_Place            357
# Gender                 357
# Alma_Mater             356
# Undergraduate_Major    335
# Graduate_Major         298
# Military_Rank          207
# Military_Branch        211
# Space_Flights          357
# Space_Flights_hr       357
# Space_Walks            357
# Space_Walks_hr         357
# Missions               334
# Death_Date              52
# Death_Mission           16
# dtype: int64

# %%
# Now I am facing two most important issues

# 1. Issue of Data types in my DataFrame of Pandas
# 2. Issue of Missig Values in my DataFrame of Pandas

# %%
data.dtypes
# Out:
# Name                    object
# Year                   float64
# Group                  float64
# Status                  object
# Birth_Date              object
# Birth_Place             object
# Gender                  object
# Alma_Mater              object
# Undergraduate_Major     object
# Graduate_Major          object
# Military_Rank           object
# Military_Branch         object
# Space_Flights            int64
# Space_Flights_hr         int64
# Space_Walks              int64
# Space_Walks_hr         float64
# Missions                object
# Death_Date              object
# Death_Mission           object
# dtype: object

# %%
data.head()
# Out:
#                Name    Year  Group   Status Birth_Date    Birth_Place Gender  \
# 0   Joseph M. Acaba  2004.0   19.0   Active  5/17/1967  Inglewood, CA   Male
# 1    Loren W. Acton     NaN    NaN  Retired   3/7/1936   Lewiston, MT   Male
# 2  James C. Adamson  1984.0   10.0  Retired   3/3/1946     Warsaw, NY   Male
# 3   Thomas D. Akers  1987.0   12.0  Retired  5/20/1951  St. Louis, MO   Male
# 4       Buzz Aldrin  1963.0    3.0  Retired  1/20/1930  Montclair, NJ   Male
#
#                                           Alma_Mater     Undergraduate_Major  \
# 0  University of California-Santa Barbara; Univer...                 Geology
# 1   Montana State University; University of Colorado     Engineering Physics
# 2          US Military Academy; Princeton University             Engineering
# 3                       University of Missouri-Rolla     Applied Mathematics
# 4                           US Military Academy; MIT  Mechanical Engineering
#
# ...

# %%
data["Year"] = pd.to_datetime(data["Year"])

data.dtypes
# Out:
# Name                           object
# Year                   datetime64[ns]
# Group                         float64
# Status                         object
# Birth_Date                     object
# Birth_Place                    object
# Gender                         object
# Alma_Mater                     object
# Undergraduate_Major            object
# Graduate_Major                 object
# Military_Rank                  object
# Military_Branch                object
# Space_Flights                   int64
# Space_Flights_hr                int64
# Space_Walks                     int64
# Space_Walks_hr                float64
# Missions                       object
# Death_Date                     object
# Death_Mission                  object
# dtype: object

# %%
# data["Birth_Date"]
data["Year"]
# Out:
# 0     1970-01-01 00:00:00.000002004
# 1                               NaT
# 2     1970-01-01 00:00:00.000001984
# 3     1970-01-01 00:00:00.000001987
# 4     1970-01-01 00:00:00.000001963
#                    ...
# 352   1970-01-01 00:00:00.000001990
# 353   1970-01-01 00:00:00.000001998
# 354   1970-01-01 00:00:00.000001966
# 355   1970-01-01 00:00:00.000001962
# 356   1970-01-01 00:00:00.000001998
# Name: Year, Length: 357, dtype: datetime64[ns]

# %%
data.dtypes
# Out:
# Name                           object
# Year                   datetime64[ns]
# Group                         float64
# Status                         object
# Birth_Date                     object
# Birth_Place                    object
# Gender                         object
# Alma_Mater                     object
# Undergraduate_Major            object
# Graduate_Major                 object
# Military_Rank                  object
# Military_Branch                object
# Space_Flights                   int64
# Space_Flights_hr                int64
# Space_Walks                     int64
# Space_Walks_hr                float64
# Missions                       object
# Death_Date                     object
# Death_Mission                  object
# dtype: object

# %%
data["Birth_Date"] = pd.to_datetime(data["Birth_Date"])
# data.dtypes

data["Birth_Date"]
# Out:
# 0     1967-05-17
# 1     1936-03-07
# 2     1946-03-03
# 3     1951-05-20
# 4     1930-01-20
#          ...
# 352   1956-08-23
# 353   1962-07-26
# 354   1932-02-07
# 355   1930-09-24
# 356   1962-06-29
# Name: Birth_Date, Length: 357, dtype: datetime64[ns]

# %%
data.dtypes
# Out:
# Name                           object
# Year                   datetime64[ns]
# Group                         float64
# Status                         object
# Birth_Date             datetime64[ns]
# Birth_Place                    object
# Gender                         object
# Alma_Mater                     object
# Undergraduate_Major            object
# Graduate_Major                 object
# Military_Rank                  object
# Military_Branch                object
# Space_Flights                   int64
# Space_Flights_hr                int64
# Space_Walks                     int64
# Space_Walks_hr                float64
# Missions                       object
# Death_Date                     object
# Death_Mission                  object
# dtype: object

# %%
data["Death_Date"] = pd.to_datetime(data["Death_Date"])
data.dtypes
# Out:
# Name                           object
# Year                   datetime64[ns]
# Group                         float64
# Status                         object
# Birth_Date             datetime64[ns]
# Birth_Place                    object
# Gender                         object
# Alma_Mater                     object
# Undergraduate_Major            object
# Graduate_Major                 object
# Military_Rank                  object
# Military_Branch                object
# Space_Flights                   int64
# Space_Flights_hr                int64
# Space_Walks                     int64
# Space_Walks_hr                float64
# Missions                       object
# Death_Date             datetime64[ns]
# Death_Mission                  object
# dtype: object

# %%
data.head(2)
# Out:
#               Name                          Year  Group   Status Birth_Date  \
# 0  Joseph M. Acaba 1970-01-01 00:00:00.000002004   19.0   Active 1967-05-17
# 1   Loren W. Acton                           NaT    NaN  Retired 1936-03-07
#
#      Birth_Place Gender                                         Alma_Mater  \
# 0  Inglewood, CA   Male  University of California-Santa Barbara; Univer...
# 1   Lewiston, MT   Male   Montana State University; University of Colorado
#
#    Undergraduate_Major Graduate_Major Military_Rank Military_Branch  \
# 0              Geology        Geology           NaN             NaN
# 1  Engineering Physics  Solar Physics           NaN             NaN
#
#    Space_Flights  Space_Flights_hr  Space_Walks  Space_Walks_hr  \
# 0              2              3307            2            13.0
# 1              1               190            0             0.0
#
#                                  Missions Death_Date Death_Mission
# ...

# %%
data["Year"] = data["Year"].astype(int)

# %%
data.dtypes
# Out:
# Name                           object
# Year                            int64
# Group                         float64
# Status                         object
# Birth_Date             datetime64[ns]
# Birth_Place                    object
# Gender                         object
# Alma_Mater                     object
# Undergraduate_Major            object
# Graduate_Major                 object
# Military_Rank                  object
# Military_Branch                object
# Space_Flights                   int64
# Space_Flights_hr                int64
# Space_Walks                     int64
# Space_Walks_hr                float64
# Missions                       object
# Death_Date             datetime64[ns]
# Death_Mission                  object
# dtype: object

# %%
data["Year"]
# Out:
# 0                     2004
# 1     -9223372036854775808
# 2                     1984
# 3                     1987
# 4                     1963
#               ...
# 352                   1990
# 353                   1998
# 354                   1966
# 355                   1962
# 356                   1998
# Name: Year, Length: 357, dtype: int64

# %%
data.dtypes
# Out:
# Name                           object
# Year                            int64
# Group                         float64
# Status                         object
# Birth_Date             datetime64[ns]
# Birth_Place                    object
# Gender                         object
# Alma_Mater                     object
# Undergraduate_Major            object
# Graduate_Major                 object
# Military_Rank                  object
# Military_Branch                object
# Space_Flights                   int64
# Space_Flights_hr                int64
# Space_Walks                     int64
# Space_Walks_hr                float64
# Missions                       object
# Death_Date             datetime64[ns]
# Death_Mission                  object
# dtype: object

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                     0
# Group                   27
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               1
# Undergraduate_Major     22
# Graduate_Major          59
# Military_Rank          150
# Military_Branch        146
# Space_Flights            0
# Space_Flights_hr         0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                23
# Death_Date             305
# Death_Mission          341
# dtype: int64

# %%
# Now I am dealing with my 'Group' Column

# %%
data["Group"].isnull().sum()

# We will deal with u laterly
# Out:
# 27

# %%
data["Status"].value_counts()
# Out:
# Retired       220
# Deceased       51
# Active         50
# Management     36
# Name: Status, dtype: int64

# %%
data["Alma_Mater"].value_counts()
# Out:
# US Naval Academy                                                 12
# US Naval Academy; US Naval Postgraduate School                   11
# US Air Force Academy; Purdue University                           7
# Purdue University                                                 7
# MIT                                                               5
#                                                                  ..
# University of Rochester; California Institute of Technology       1
# California Polytechnic Institute                                  1
# Muskingum College                                                 1
# Southeast Missouri State; University of Missouri                  1
# MIT; University of Texas-Austin; George Washington University     1
# Name: Alma_Mater, Length: 280, dtype: int64

# %%
data["Alma_Mater"].unique()
# Out:
# array(['University of California-Santa Barbara; University of Arizona',
#        'Montana State University; University of Colorado',
#        'US Military Academy; Princeton University',
#        'University of Missouri-Rolla', 'US Military Academy; MIT',
#        'Villanova University; University of Florida',
#        'DePauw University; Yale University',
#        'University of Illinois; US Naval Postgraduate School',
#        'US Naval Academy; Air Force Institute of Technology',
#        'Hastings College; Iowa State University',
#        'University of Washington; Creighton University',
#        'MIT; University of Washington', 'Harvard University; MIT',
#        'University of Illinois-Urbana',
#        'Purdue University; University of Southern California',
#        'Frostburg State University; University of Maryland',
#        'University of Idaho; University of Tennessee',
#        'George Washington University; University of Texas',
# ...

# %%
# An Example for the better understanding of my Unique

pd.Series([1,2,4,53,89,3,2 , 3 , 5 ,4 ,53]).unique()
# Unique never adds the repititive values
# Out:
# array([ 1,  2,  4, 53, 89,  3,  5])

# %%
pd.Series([1,2,4,53,89,3,2 , 3 , 5 ,4 ,53]).nunique()
# nUnique tells about the actual numbers of unique values present in an an array
# Out:
# 7

# %%
data.head()
# Out:
#                Name                 Year  Group   Status Birth_Date  \
# 0   Joseph M. Acaba                 2004   19.0   Active 1967-05-17
# 1    Loren W. Acton -9223372036854775808    NaN  Retired 1936-03-07
# 2  James C. Adamson                 1984   10.0  Retired 1946-03-03
# 3   Thomas D. Akers                 1987   12.0  Retired 1951-05-20
# 4       Buzz Aldrin                 1963    3.0  Retired 1930-01-20
#
#      Birth_Place Gender                                         Alma_Mater  \
# 0  Inglewood, CA   Male  University of California-Santa Barbara; Univer...
# 1   Lewiston, MT   Male   Montana State University; University of Colorado
# 2     Warsaw, NY   Male          US Military Academy; Princeton University
# 3  St. Louis, MO   Male                       University of Missouri-Rolla
# 4  Montclair, NJ   Male                           US Military Academy; MIT
#
#       Undergraduate_Major         Graduate_Major Military_Rank  \
# ...

# %%
# Masking concept in pandas

data["Death_Mission"].unique()
data["Death_Mission"].nunique()
# Out:
# 3

# %%
data[data.notnull()]
# This is the method if I wanna find out my all missing values in my data set
# Out:
#                       Name                 Year  Group   Status Birth_Date  \
# 0          Joseph M. Acaba                 2004   19.0   Active 1967-05-17
# 1           Loren W. Acton -9223372036854775808    NaN  Retired 1936-03-07
# 2         James C. Adamson                 1984   10.0  Retired 1946-03-03
# 3          Thomas D. Akers                 1987   12.0  Retired 1951-05-20
# 4              Buzz Aldrin                 1963    3.0  Retired 1930-01-20
# ..                     ...                  ...    ...      ...        ...
# 352          David A. Wolf                 1990   13.0  Retired 1956-08-23
# 353  Neil W. Woodward III                  1998   17.0  Retired 1962-07-26
# 354       Alfred M. Worden                 1966    5.0  Retired 1932-02-07
# 355          John W. Young                 1962    2.0  Retired 1930-09-24
# 356        George D. Zamka                 1998   17.0  Retired 1962-06-29
#
#            Birth_Place Gender  \
# 0        Inglewood, CA   Male
# ...

# %% [markdown]
# # Handling Missing Values In Detail
# # A to Z Concept Complete

# %%
# There are two possibilities

# - Fill the missing values
# - Drop the missing values

# %%
# First let's talk about Year Columns

# data["Year"] = data["Year"].fillna(data["Year"].isnull())

# %%
data["Year"] = data["Year"].fillna(data["Year"].mode())

# %%
# data["Year"].isnull().sum()

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                     0
# Group                   27
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               1
# Undergraduate_Major     22
# Graduate_Major          59
# Military_Rank          150
# Military_Branch        146
# Space_Flights            0
# Space_Flights_hr         0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                23
# Death_Date             305
# Death_Mission          341
# dtype: int64

# %%
data["Group"].mode()
# Out:
# 0     8.0
# 1    16.0
# Name: Group, dtype: float64

# %%
data["Group"].fillna(data["Group"].mode().mean(), inplace = True)

# %%
# data["Group"].isnull().sum()

# %%
data["Group"].isnull().sum()
# Out:
# 0

# %%
# data["Group"].fillna(data["Group"].mode() , inplace = True)

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                     0
# Group                    0
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               1
# Undergraduate_Major     22
# Graduate_Major          59
# Military_Rank          150
# Military_Branch        146
# Space_Flights            0
# Space_Flights_hr         0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                23
# Death_Date             305
# Death_Mission          341
# dtype: int64

# %%
# data["Alma_Mater"].mode()
# also fill one missing value in this Alma Mater too

# data["Alma_Mater"].fillna(data["Alma_Mater"].mode() , inplace = True)
# data["Alma_Mater"].fillna(data["Alma_Mater"].mode())

# %%
data["Alma_Mater"].fillna(data["Alma_Mater"].mode().iloc[0] , inplace = True)

# %%
data["Alma_Mater"].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                     0
# Group                    0
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               0
# Undergraduate_Major     22
# Graduate_Major          59
# Military_Rank          150
# Military_Branch        146
# Space_Flights            0
# Space_Flights_hr         0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                23
# Death_Date             305
# Death_Mission          341
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                     0
# Group                    0
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               1
# Undergraduate_Major     22
# Graduate_Major          59
# Military_Rank          150
# Military_Branch        146
# Space_Flights            0
# Space_Flights_hr         0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                23
# Death_Date             305
# Death_Mission          341
# dtype: int64

# %%
# Filling the remaining values in the data set

data.isnull().sum()
# Out:
# Name                     0
# Year                     0
# Group                    0
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               0
# Undergraduate_Major     22
# Graduate_Major          59
# Military_Rank          150
# Military_Branch        146
# Space_Flights            0
# Space_Flights_hr         0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                23
# Death_Date             305
# Death_Mission          341
# dtype: int64

# %%
data["Undergraduate_Major"].isnull().sum()
# Out:
# 22

# %%
data["Undergraduate_Major"].fillna(data['Undergraduate_Major'].mode().iloc[0], inplace = True )

# %%
data["Undergraduate_Major"].isnull().sum()
# Out:
# 0

# %%
data["Graduate_Major"].fillna(data["Graduate_Major"].mode().iloc[0] , inplace = True)

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                     0
# Group                    0
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               0
# Undergraduate_Major      0
# Graduate_Major           0
# Military_Rank          150
# Military_Branch        146
# Space_Flights            0
# Space_Flights_hr         0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                23
# Death_Date             305
# Death_Mission          341
# dtype: int64

# %%
data["Missions"].fillna(data["Missions"].mode().iloc[0], inplace = True )

# %%
data["Missions"].isnull().sum()
# Out:
# 0

# %%
data.isnull().sum()
# Out:
# Name                     0
# Year                     0
# Group                    0
# Status                   0
# Birth_Date               0
# Birth_Place              0
# Gender                   0
# Alma_Mater               0
# Undergraduate_Major      0
# Graduate_Major           0
# Military_Rank          150
# Military_Branch        146
# Space_Flights            0
# Space_Flights_hr         0
# Space_Walks              0
# Space_Walks_hr           0
# Missions                 0
# Death_Date             305
# Death_Mission          341
# dtype: int64

# %% [markdown]
# ---
# # Class # 03 Pandas DataFrame class has been completely covered today
# ---
