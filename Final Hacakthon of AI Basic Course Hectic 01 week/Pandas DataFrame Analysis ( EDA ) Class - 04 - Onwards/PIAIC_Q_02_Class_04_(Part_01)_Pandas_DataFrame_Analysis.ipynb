# %%
import pandas as pd
import numpy as np

# %%
# create a dictionary data set

students = {

            "student_id" : ["3452" , "9453"] ,
            "student_Name" : ["Owais" , "Ali"],
            "student_Mode" : ["Online" , "Onsite"]

}

# %%
students
# Out:
# {'student_id': ['3452', '9453'],
#  'student_Name': ['Owais', 'Ali'],
#  'student_Mode': ['Online', 'Onsite']}

# %%
students_Data = pd.DataFrame(students)

# %%
students_Data
# Out:
#   student_id student_Name student_Mode
# 0       3452        Owais       Online
# 1       9453          Ali       Onsite

# %%
students_Data["student_id"] = students_Data["student_id"].reset_index(inplace = True , drop = True)

# %%
students_Data["student_id"]
# Out:
# 0    None
# 1    None
# Name: student_id, dtype: object

# %%
students_Data
# Out:
#   student_id student_Name student_Mode
# 0       None        Owais       Online
# 1       None          Ali       Onsite

# %% [markdown]
# # Merging In Pandas

# %%
# Undesrstand all these concepts from the online class of PIAIC without practice

# %% [markdown]
# # I will continue it after the completion of Hackathon of Basic AI Course Hope to Skills In SHa ALLAh
# ---
